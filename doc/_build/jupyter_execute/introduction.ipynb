# %% [markdown]
# (introduction)=
#
# ## Some introduction stuff
#
# hello world!

# %% [markdown]
# ## Details about this book
#
# This book was compiled with the following version of Python:

# %%
# remove-input
import sys

print("Compiled with Python version:", sys.version)
# Out:
# Compiled with Python version: 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 12:22:05) [Clang 14.0.6 ]
